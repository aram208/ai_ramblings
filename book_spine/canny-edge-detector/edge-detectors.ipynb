# %%
import cv2 as cv
#import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ### Detect using adaptive thresholds

# %%
img = cv.imread('1.jpg',0)

img = cv.medianBlur(img,5)

ret,th1 = cv.threshold(img,127,255,cv.THRESH_BINARY)

th2 = cv.adaptiveThreshold(img,255,cv.ADAPTIVE_THRESH_MEAN_C, cv.THRESH_BINARY,11,2)
th3 = cv.adaptiveThreshold(img,255,cv.ADAPTIVE_THRESH_GAUSSIAN_C, cv.THRESH_BINARY,11,2)

titles = ['Original Image', 'Global Thresholding (v = 127)',
            'Adaptive Mean Thresholding', 'Adaptive Gaussian Thresholding']
images = [img, th1, th2, th3]

for i in range(4):
    plt.subplot(2,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
    
plt.show()

# %% [markdown]
# ### Canny Edge Detector

# %%
edges = cv.Canny(img, 50, 50)
cv.imwrite("1_canny.jpg", edges)

# %% [markdown]
# ![alt text](1_canny.jpg "Title")

# %% [markdown]
# ### Harris Corner Detection

# %%
img = cv.imread('1.jpg',0)
harris = cv.cornerHarris(src = img, blockSize = 4, ksize = 11, k = 0, borderType = cv.BORDER_CONSTANT)
cv.imwrite("1_harris.jpg", harris)

# %% [markdown]
# ![alt text](1_harris.jpg "Title")

# %% [markdown]
# ### Hough Lines
# ![alt text](1_hough_3.jpg "Hough lines")
